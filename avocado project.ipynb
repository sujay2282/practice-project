# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('avocado.csv')

# %%
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0               0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1               1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2               2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3               3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4               4  2015-11-29          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 18244           7  2018-02-04          1.63      17074.83  2046.96    1529.20
# 18245           8  2018-01-28          1.71      13888.04  1191.70    3431.50
# 18246           9  2018-01-21          1.87      13766.76  1191.92    2452.79
# 18247          10  2018-01-14          1.93      16205.22  1527.63    2981.04
# 18248          11  2018-01-07          1.62      17489.58  2894.77    2356.13
#
# ...

# %%
df.isnull().sum()
# Out:
# Unnamed: 0      0
# Date            0
# AveragePrice    0
# Total Volume    0
# 4046            0
# 4225            0
# 4770            0
# Total Bags      0
# Small Bags      0
# Large Bags      0
# XLarge Bags     0
# type            0
# year            0
# region          0
# dtype: int64

# %% [markdown]
# in that data set there are no null value are present

# %%
df['year'].value_counts()
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=df.select_dtypes(object)

# %%
df1
# Out:
#              Date          type            region
# 0      2015-12-27  conventional            Albany
# 1      2015-12-20  conventional            Albany
# 2      2015-12-13  conventional            Albany
# 3      2015-12-06  conventional            Albany
# 4      2015-11-29  conventional            Albany
# ...           ...           ...               ...
# 18244  2018-02-04       organic  WestTexNewMexico
# 18245  2018-01-28       organic  WestTexNewMexico
# 18246  2018-01-21       organic  WestTexNewMexico
# 18247  2018-01-14       organic  WestTexNewMexico
# 18248  2018-01-07       organic  WestTexNewMexico
#
# [18249 rows x 3 columns]

# %%
for i in df1:
    le=LabelEncoder()
    df1[i]=le.fit_transform(df1[i])

# %%
df1
# Out:
#        Date  type  region
# 0        51     0       0
# 1        50     0       0
# 2        49     0       0
# 3        48     0       0
# 4        47     0       0
# ...     ...   ...     ...
# 18244   161     1      53
# 18245   160     1      53
# 18246   159     1      53
# 18247   158     1      53
# 18248   157     1      53
#
# [18249 rows x 3 columns]

# %%
df2=df.select_dtypes(float)

# %%
df2
# Out:
#        AveragePrice  Total Volume     4046       4225    4770  Total Bags  \
# 0              1.33      64236.62  1036.74   54454.85   48.16     8696.87
# 1              1.35      54876.98   674.28   44638.81   58.33     9505.56
# 2              0.93     118220.22   794.70  109149.67  130.50     8145.35
# 3              1.08      78992.15  1132.00   71976.41   72.58     5811.16
# 4              1.28      51039.60   941.48   43838.39   75.78     6183.95
# ...             ...           ...      ...        ...     ...         ...
# 18244          1.63      17074.83  2046.96    1529.20    0.00    13498.67
# 18245          1.71      13888.04  1191.70    3431.50    0.00     9264.84
# 18246          1.87      13766.76  1191.92    2452.79  727.94     9394.11
# 18247          1.93      16205.22  1527.63    2981.04  727.01    10969.54
# 18248          1.62      17489.58  2894.77    2356.13  224.53    12014.15
#
#        Small Bags  Large Bags  XLarge Bags
# ...

# %%
sujay=pd.concat([df1 , df2], axis=1)

# %%
sujay
# Out:
#        Date  type  region  AveragePrice  Total Volume     4046       4225  \
# 0        51     0       0          1.33      64236.62  1036.74   54454.85
# 1        50     0       0          1.35      54876.98   674.28   44638.81
# 2        49     0       0          0.93     118220.22   794.70  109149.67
# 3        48     0       0          1.08      78992.15  1132.00   71976.41
# 4        47     0       0          1.28      51039.60   941.48   43838.39
# ...     ...   ...     ...           ...           ...      ...        ...
# 18244   161     1      53          1.63      17074.83  2046.96    1529.20
# 18245   160     1      53          1.71      13888.04  1191.70    3431.50
# 18246   159     1      53          1.87      13766.76  1191.92    2452.79
# 18247   158     1      53          1.93      16205.22  1527.63    2981.04
# 18248   157     1      53          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18249 entries, 0 to 18248
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    18249 non-null  int64
#  1   Date          18249 non-null  object
#  2   AveragePrice  18249 non-null  float64
#  3   Total Volume  18249 non-null  float64
#  4   4046          18249 non-null  float64
#  5   4225          18249 non-null  float64
#  6   4770          18249 non-null  float64
#  7   Total Bags    18249 non-null  float64
#  8   Small Bags    18249 non-null  float64
#  9   Large Bags    18249 non-null  float64
#  10  XLarge Bags   18249 non-null  float64
#  11  type          18249 non-null  object
#  12  year          18249 non-null  int64
#  13  region        18249 non-null  object
# dtypes: float64(9), int64(2), object(3)
# memory usage: 1.9+ MB

# %%
df3=df.select_dtypes(int)

# %%
df3
# Out:
#        Unnamed: 0  year
# 0               0  2015
# 1               1  2015
# 2               2  2015
# 3               3  2015
# 4               4  2015
# ...           ...   ...
# 18244           7  2018
# 18245           8  2018
# 18246           9  2018
# 18247          10  2018
# 18248          11  2018
#
# [18249 rows x 2 columns]

# %%
data=pd.concat([sujay , df3], axis=1)

# %%
data
# Out:
#        Date  type  region  AveragePrice  Total Volume     4046       4225  \
# 0        51     0       0          1.33      64236.62  1036.74   54454.85
# 1        50     0       0          1.35      54876.98   674.28   44638.81
# 2        49     0       0          0.93     118220.22   794.70  109149.67
# 3        48     0       0          1.08      78992.15  1132.00   71976.41
# 4        47     0       0          1.28      51039.60   941.48   43838.39
# ...     ...   ...     ...           ...           ...      ...        ...
# 18244   161     1      53          1.63      17074.83  2046.96    1529.20
# 18245   160     1      53          1.71      13888.04  1191.70    3431.50
# 18246   159     1      53          1.87      13766.76  1191.92    2452.79
# 18247   158     1      53          1.93      16205.22  1527.63    2981.04
# 18248   157     1      53          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags  Unnamed: 0  \
# ...

# %% [markdown]
# we see that all the data in the numaric form we get the EDA process on this data

# %% [markdown]
# in that data set our main goal is the output of the data sets are region as well as average price

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
sns.scatterplot(x='Date', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='Date', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='Total Volume', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='4046', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='4046', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='4225', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='4225', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='4770', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='4770', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='Total Bags', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='Total Bags', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='Small Bags', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='Small Bags', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='Large Bags', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='Large Bags', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='XLarge Bags', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='type', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='type', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='year', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='year', ylabel='AveragePrice'>

# %%
sns.scatterplot(x='region', y= 'AveragePrice', data=data)
# Out:
# <AxesSubplot:xlabel='region', ylabel='AveragePrice'>

# %% [markdown]
# we see that all columns and there scatter distribution

# %%
sns.countplot('AveragePrice', data=data)
print(data['AveragePrice'].value_counts())
# Out:
# 1.15    202
# 1.18    199
# 1.08    194
# 1.26    193
# 1.13    192
#        ...
# 3.25      1
# 3.12      1
# 2.68      1
# 3.03      1
# 3.17      1
# Name: AveragePrice, Length: 259, dtype: int64

# %%
sns.countplot('region', data=data)
print(data['region'].value_counts())
# Out:
# 0     338
# 40    338
# 29    338
# 30    338
# 31    338
# 32    338
# 33    338
# 34    338
# 35    338
# 36    338
# 37    338
# 38    338
# 39    338
# 41    338
# 1     338
# 42    338
# 43    338
# 44    338
# 45    338
# 46    338
# 47    338
# 48    338
# 49    338
# 50    338
# 51    338
# 52    338
# 28    338
# 27    338
# 26    338
# 25    338
# 2     338
# 3     338
# 4     338
# 5     338
# 6     338
# 7     338
# 8     338
# 9     338
# 10    338
# 11    338
# 12    338
# 13    338
# 14    338
# 15    338
# 16    338
# 17    338
# 18    338
# 19    338
# 20    338
# 21    338
# 22    338
# 23    338
# 24    338
# 53    335
# Name: region, dtype: int64

# %% [markdown]
# we see that there all 338 each on all the region

# %%
sns.countplot('year', data=data)
print(data['year'].value_counts())
# Out:
# 2017    5722
# 2016    5616
# 2015    5615
# 2018    1296
# Name: year, dtype: int64

# %% [markdown]
# we see that there are all years are product are same distributed

# %%
sns.countplot('type', data=data)
print(data['type'].value_counts())
# Out:
# 0    9126
# 1    9123
# Name: type, dtype: int64

# %%
sns.countplot('Unnamed: 0', data=data)
print(data['Unnamed: 0'].value_counts())
# Out:
# 0     432
# 7     432
# 1     432
# 11    432
# 9     432
# 8     432
# 10    432
# 6     432
# 5     432
# 4     432
# 3     432
# 2     432
# 41    324
# 34    324
# 35    324
# 36    324
# 37    324
# 38    324
# 39    324
# 40    324
# 47    324
# 42    324
# 43    324
# 44    324
# 45    324
# 46    324
# 32    324
# 48    324
# 49    324
# 50    324
# 33    324
# 26    324
# 31    324
# 30    324
# 12    324
# 13    324
# 14    324
# 15    324
# 16    324
# 17    324
# 18    324
# 19    324
# 20    324
# 21    324
# 22    324
# 23    324
# 24    324
# 25    324
# 27    324
# 28    324
# 29    324
# 51    322
# 52    107
# Name: Unnamed: 0, dtype: int64

# %% [markdown]
# we see the distribution of the data

# %% [markdown]
# then we describe the data

# %%
data.describe()
# Out:
#                Date          type        region  AveragePrice  Total Volume  \
# count  18249.000000  18249.000000  18249.000000  18249.000000  1.824900e+04
# mean      83.997096      0.499918     26.495644      1.405978  8.506440e+05
# std       48.787638      0.500014     15.583788      0.402677  3.453545e+06
# min        0.000000      0.000000      0.000000      0.440000  8.456000e+01
# 25%       42.000000      0.000000     13.000000      1.100000  1.083858e+04
# 50%       84.000000      0.000000     26.000000      1.370000  1.073768e+05
# 75%      126.000000      1.000000     40.000000      1.660000  4.329623e+05
# max      168.000000      1.000000     53.000000      3.250000  6.250565e+07
#
#                4046          4225          4770    Total Bags    Small Bags  \
# count  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04  1.824900e+04
# mean   2.930084e+05  2.951546e+05  2.283974e+04  2.396392e+05  1.821947e+05
# ...

# %% [raw]
# in that dataset wee see that the all columns mean values and standard deviation.
#
# all columns information is see in describtion minimun values of the each column
# 25th percentile of each column
# 50th percentile of each column
# 75th percentile of the each column
# as well as we see the maximum value of the each columns.
# we see the count of each columns are present in respresctive column

# %% [markdown]
# after that we correlation

# %%
ss=data.corr()
ss
# Out:
#                   Date      type    region  AveragePrice  Total Volume  \
# Date          1.000000 -0.000060 -0.000101      0.145514      0.009263
# type         -0.000060  1.000000 -0.000280      0.615845     -0.232434
# region       -0.000101 -0.000280  1.000000     -0.011716      0.174176
# AveragePrice  0.145514  0.615845 -0.011716      1.000000     -0.192752
# Total Volume  0.009263 -0.232434  0.174176     -0.192752      1.000000
# 4046         -0.005028 -0.225819  0.192073     -0.208317      0.977863
# 4225         -0.016895 -0.232289  0.145726     -0.172928      0.974181
# 4770         -0.047517 -0.210027  0.095252     -0.179446      0.872202
# Total Bags    0.064688 -0.217788  0.175256     -0.177088      0.963047
# Small Bags    0.056902 -0.220535  0.164702     -0.174730      0.967238
# Large Bags    0.081855 -0.193177  0.198768     -0.172940      0.880640
# XLarge Bags   0.077374 -0.175483  0.082281     -0.117592      0.747157
# ...

# %%
plt.figure(figsize=(10,6))
sns.heatmap(ss, cmap='Blues', annot=True)
# Out:
# <AxesSubplot:>

# %% [raw]
# we see that the our target variable are the region and averageprice and see the correlation with that columns.
# the correlation is near to 1 is sign that there are very good correlation with each others.
# the correlation is near to 0 is sign that there are very bad correlation with each others.

# %%
data.corr()['region']
# Out:
# Date           -0.000101
# type           -0.000280
# region          1.000000
# AveragePrice   -0.011716
# Total Volume    0.174176
# 4046            0.192073
# 4225            0.145726
# 4770            0.095252
# Total Bags      0.175256
# Small Bags      0.164702
# Large Bags      0.198768
# XLarge Bags     0.082281
# Unnamed: 0     -0.000489
# year           -0.000055
# Name: region, dtype: float64

# %% [markdown]
# we see that correlation with region is not very good to all the columns.

# %%
data.corr()['AveragePrice'].sort_values()
# Out:
# 4046           -0.208317
# Total Volume   -0.192752
# 4770           -0.179446
# Total Bags     -0.177088
# Small Bags     -0.174730
# Large Bags     -0.172940
# 4225           -0.172928
# Unnamed: 0     -0.133008
# XLarge Bags    -0.117592
# region         -0.011716
# year            0.093197
# Date            0.145514
# type            0.615845
# AveragePrice    1.000000
# Name: AveragePrice, dtype: float64

# %% [markdown]
# there also the correlation with AveragePrice is not good with all other columns.

# %%
d=data.skew()
d
# Out:
# Date             0.000117
# type             0.000329
# region           0.000030
# AveragePrice     0.580303
# Total Volume     9.007687
# 4046             8.648220
# 4225             8.942466
# 4770            10.159396
# Total Bags       9.756072
# Small Bags       9.540660
# Large Bags       9.796455
# XLarge Bags     13.139751
# Unnamed: 0       0.108334
# year             0.215339
# dtype: float64

# %% [markdown]
# we see that the skewness is greather than the 5 is very bad skewness so we delete this columns.

# %%
sns.distplot(df['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %%
sns.distplot(data['region'])
# Out:
# <AxesSubplot:xlabel='region', ylabel='Density'>

# %%
sns.distplot(df['XLarge Bags'])
# Out:
# <AxesSubplot:xlabel='XLarge Bags', ylabel='Density'>

# %%
sns.catplot(x="region", y="AveragePrice", data=df)

# %%
sns.kdeplot(data['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# we see that the the average price of the product is around 1 to 1.5 doller

# %%
data.AveragePrice.unique()
# Out:
# array([1.33, 1.35, 0.93, 1.08, 1.28, 1.26, 0.99, 0.98, 1.02, 1.07, 1.12,
#        1.31, 1.11, 1.34, 1.45, 1.05, 1.37, 1.27, 1.32, 1.23, 1.19, 1.43,
#        1.2 , 1.22, 1.13, 1.16, 1.06, 1.17, 1.24, 0.96, 1.  , 1.09, 0.95,
#        0.97, 1.15, 1.01, 1.14, 1.1 , 1.04, 1.03, 1.18, 1.29, 1.25, 0.71,
#        0.94, 0.91, 1.39, 1.4 , 1.36, 1.3 , 1.54, 1.59, 1.56, 1.38, 1.49,
#        1.5 , 1.47, 1.42, 1.41, 1.44, 1.52, 0.9 , 0.87, 0.78, 0.92, 0.83,
#        0.88, 0.84, 0.85, 1.21, 0.79, 0.89, 0.86, 0.8 , 0.82, 0.74, 0.81,
#        0.77, 0.75, 0.65, 0.73, 0.68, 0.72, 0.67, 0.76, 0.62, 0.7 , 0.66,
#        1.46, 0.49, 0.53, 0.56, 0.6 , 0.58, 0.54, 0.52, 0.51, 0.57, 0.63,
#        0.64, 0.61, 1.48, 1.55, 1.58, 1.53, 1.57, 1.51, 0.69, 1.62, 1.63,
#        1.61, 1.6 , 1.73, 1.8 , 1.86, 1.85, 1.69, 1.66, 1.65, 1.64, 1.67,
#        1.68, 1.82, 2.07, 1.84, 1.83, 1.7 , 1.72, 1.81, 1.78, 0.59, 1.9 ,
#        1.93, 1.99, 1.95, 1.89, 1.76, 1.71, 1.74, 0.55, 1.79, 1.75, 1.94,
# ...

# %%
plt.hist('AveragePrice',data=data, bins=10)
# Out:
# (array([ 331., 2632., 4824., 4506., 3412., 1672.,  598.,  177.,   86.,
#           11.]),
#  array([0.44 , 0.721, 1.002, 1.283, 1.564, 1.845, 2.126, 2.407, 2.688,
#         2.969, 3.25 ]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# we see that the average price is around 1.2 to 1.8

# %%
plt.hist('region',data=data, bins=10)
# Out:
# (array([2028., 1690., 1690., 2028., 1690., 1690., 2028., 1690., 1690.,
#         2025.]),
#  array([ 0. ,  5.3, 10.6, 15.9, 21.2, 26.5, 31.8, 37.1, 42.4, 47.7, 53. ]),
#  <BarContainer object of 10 artists>)

# %%
dd=df.corr()['AveragePrice']
dd
# Out:
# Unnamed: 0     -0.133008
# AveragePrice    1.000000
# Total Volume   -0.192752
# 4046           -0.208317
# 4225           -0.172928
# 4770           -0.179446
# Total Bags     -0.177088
# Small Bags     -0.174730
# Large Bags     -0.172940
# XLarge Bags    -0.117592
# year            0.093197
# Name: AveragePrice, dtype: float64

# %% [markdown]
# checking the outliers

# %%
sns.distplot(data['AveragePrice'])
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Density'>

# %% [markdown]
# we see that there are not such o outliers are present

# %%
sns.distplot(data['Total Volume'])
# Out:
# <AxesSubplot:xlabel='Total Volume', ylabel='Density'>

# %% [markdown]
# here also here skewness is present

# %%
data['AveragePrice'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present

# %%
data['Total Volume'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['XLarge Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['4046'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['4770'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Total Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %%
data['Small Bags'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# in all columns the outliers are present so we clear the outliers.

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(data))
threshold=2
np.where(z>2)
# Out:
# (array([  313,   324,   326, ..., 18111, 18113, 18116], dtype=int64),
#  array([7, 6, 7, ..., 3, 3, 3], dtype=int64))

# %%
data_new=data[(z<2).all(axis=1)]
data_new
# Out:
#        Date  type  region  AveragePrice  Total Volume     4046       4225  \
# 0        51     0       0          1.33      64236.62  1036.74   54454.85
# 1        50     0       0          1.35      54876.98   674.28   44638.81
# 2        49     0       0          0.93     118220.22   794.70  109149.67
# 3        48     0       0          1.08      78992.15  1132.00   71976.41
# 4        47     0       0          1.28      51039.60   941.48   43838.39
# ...     ...   ...     ...           ...           ...      ...        ...
# 18244   161     1      53          1.63      17074.83  2046.96    1529.20
# 18245   160     1      53          1.71      13888.04  1191.70    3431.50
# 18246   159     1      53          1.87      13766.76  1191.92    2452.79
# 18247   158     1      53          1.93      16205.22  1527.63    2981.04
# 18248   157     1      53          1.62      17489.58  2894.77    2356.13
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags  Unnamed: 0  \
# ...

# %%
x=data.drop("AveragePrice", axis=1)
y=data["AveragePrice"]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.58305373, -0.99983562, -2.01155231, ..., -0.69984934,
#         -1.96884484, -1.22189489],
#        [-0.60532524, -0.99983562, -2.01155231, ..., -0.69984934,
#         -1.79261949, -1.22189489],
#        [-0.62772182, -0.99983562, -2.01155231, ..., -0.69984934,
#         -1.64836645, -1.22189489],
#        ...,
#        [ 1.40879579,  1.00016441,  1.54383806, ..., -0.69984934,
#         -0.92773458,  1.96854784],
#        [ 1.39266926,  1.00016441,  1.54383806, ..., -0.69984934,
#         -0.84428599,  1.96854784],
#        [ 1.37651374,  1.00016441,  1.54383806, ..., -0.69984934,
#         -0.76366872,  1.96854784]])

# %%
y
# Out:
# 0        1.33
# 1        1.35
# 2        0.93
# 3        1.08
# 4        1.28
#          ...
# 18244    1.63
# 18245    1.71
# 18246    1.87
# 18247    1.93
# 18248    1.62
# Name: AveragePrice, Length: 18249, dtype: float64

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.58305373, -0.99983562, -2.01155231, ..., -0.69984934,
#         -1.96884484, -1.22187884],
#        [-0.60532524, -0.99983562, -2.01155231, ..., -0.69984934,
#         -1.79261949, -1.22187884],
#        [-0.62772182, -0.99983562, -2.01155231, ..., -0.69984934,
#         -1.64836645, -1.22187884],
#        ...,
#        [ 1.40879579,  1.00016441,  1.54383806, ..., -0.69984934,
#         -0.92773458,  1.96856389],
#        [ 1.39266926,  1.00016441,  1.54383806, ..., -0.69984934,
#         -0.84428599,  1.96856389],
#        [ 1.37651374,  1.00016441,  1.54383806, ..., -0.69984934,
#         -0.76366872,  1.96856389]])

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# only for the selection the random value
for i in range(0,100):
    x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=i)
    lr.fit(x_train , y_train)
    pred_train=lr.predict(x_train)
    pred_test=lr.predict(x_test)
    print(f"at random state {i}, the traing accuracy is- {r2_score(y_train,pred_train)}")
    print(f"at random state {i}, the testing accuracy is-{r2_score(y_test,pred_test)}")
    print('\n')
# Out:
# at random state 0, the traing accuracy is- 0.5575001310125778
# at random state 0, the testing accuracy is-0.5532137858683046
#
#
# at random state 1, the traing accuracy is- 0.5549689921394909
# at random state 1, the testing accuracy is-0.5640050062226103
#
#
# at random state 2, the traing accuracy is- 0.5588685261705671
# at random state 2, the testing accuracy is-0.5480230521539335
#
#
# at random state 3, the traing accuracy is- 0.5550641432004003
# at random state 3, the testing accuracy is-0.563887468737703
#
#
# at random state 4, the traing accuracy is- 0.5604203078518761
# at random state 4, the testing accuracy is-0.5420607801126682
#
#
# at random state 5, the traing accuracy is- 0.556906319415442
# at random state 5, the testing accuracy is-0.5552033928922248
#
#
# at random state 6, the traing accuracy is- 0.5557077698595915
# at random state 6, the testing accuracy is-0.5608363610255871
#
#
# at random state 7, the traing accuracy is- 0.5568911091435865
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=27)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.5703026816713848

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test , y=pred_test, color='r')
plt.xlabel('actual charger')
plt.ylabel('predicted charger')
plt.title('Linear regression ')
plt.show()

# %% [markdown]
# we see that the this show the regression.

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train, y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss=r2_score(y_test, pred_ls)
lss
# Out:
# 0.5675599662301081

# %% [markdown]
# we see the Averageprice to all the columns. then we see the regression to region column

# %%
x=data.drop("region", axis=1)
y=data["region"]

# %%
from sklearn.preprocessing import power_transform
x=power_transform(x,method='yeo-johnson')

# %%
x
# Out:
# array([[-0.58305373, -0.99983562, -0.08624822, ..., -0.69984934,
#         -1.96884484, -1.22189489],
#        [-0.60532524, -0.99983562, -0.03402196, ..., -0.69984934,
#         -1.79261949, -1.22189489],
#        [-0.62772182, -0.99983562, -1.27393796, ..., -0.69984934,
#         -1.64836645, -1.22189489],
#        ...,
#        [ 1.40879579,  1.00016441,  1.14779044, ..., -0.69984934,
#         -0.92773458,  1.96854784],
#        [ 1.39266926,  1.00016441,  1.2658763 , ..., -0.69984934,
#         -0.84428599,  1.96854784],
#        [ 1.37651374,  1.00016441,  0.61828746, ..., -0.69984934,
#         -0.76366872,  1.96854784]])

# %%
y
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 18244    53
# 18245    53
# 18246    53
# 18247    53
# 18248    53
# Name: region, Length: 18249, dtype: int32

# %%
from sklearn.preprocessing import StandardScaler
sc=StandardScaler()
x=sc.fit_transform(x)
x
# Out:
# array([[-0.58305373, -0.99983562, -0.08624822, ..., -0.69984934,
#         -1.96884484, -1.22187884],
#        [-0.60532524, -0.99983562, -0.03402196, ..., -0.69984934,
#         -1.79261949, -1.22187884],
#        [-0.62772182, -0.99983562, -1.27393796, ..., -0.69984934,
#         -1.64836645, -1.22187884],
#        ...,
#        [ 1.40879579,  1.00016441,  1.14779044, ..., -0.69984934,
#         -0.92773458,  1.96856389],
#        [ 1.39266926,  1.00016441,  1.2658763 , ..., -0.69984934,
#         -0.84428599,  1.96856389],
#        [ 1.37651374,  1.00016441,  0.61828746, ..., -0.69984934,
#         -0.76366872,  1.96856389]])

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=22)

# %%
lr.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(x_test)

# %%
print(r2_score(y_test,pred_test))
# Out:
# 0.0957834505331363

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=y_test , y=pred_test, color='r')
plt.xlabel('actual charger')
plt.ylabel('predicted charger')
plt.title('Linear regression ')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(x_train, y_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.001,random_state=0)
ls.fit(x_train,y_train)
ls.score(x_train,y_train)
pred_ls = ls.predict(x_test)

lss=r2_score(y_test, pred_ls)
lss
# Out:
# 0.09579221124648052

# %%
cv_score=cross_val_score(ls,x,y,cv=3)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.16448704996902555
