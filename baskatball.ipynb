# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('basketball.csv')

# %%
df
# Out:
#      runs  at_bats  hits  doubles  triples  homeruns  walks  strikeouts  \
# 95    724     5575  1497      300       42       139    383         973
# 83    696     5467  1349      277       44       156    439        1264
# 81    669     5439  1395      303       29       141    533        1157
# 76    622     5533  1381      260       27       136    404        1231
# 74    689     5605  1515      289       49       151    455        1259
# 93    891     5509  1480      308       17       232    570        1151
# 87    764     5567  1397      272       19       212    554        1227
# 81    713     5485  1370      246       20       217    418        1331
# 80    644     5485  1383      278       32       167    436        1310
# 78    748     5640  1495      294       33       161    478        1148
# 88    751     5511  1419      279       32       172    503        1233
# 86    729     5459  1363      278       26       230    486        1392
# ...

# %%
df.shape
# Out:
# (30, 16)

# %% [markdown]
# in that dataset the number of rows are 30 and the number of columns are 16

# %%
df.isnull().sum()
# Out:
# runs             0
# at_bats          0
# hits             0
# doubles          0
# triples          0
# homeruns         0
# walks            0
# strikeouts       0
# stolen_bases     0
# runs_allowed     0
# earned_runs      0
# ERA              0
# shutouts         0
# saves            0
# complete_game    0
# win              0
# dtype: int64

# %% [markdown]
# in that dataset the number of null values are 0 so the data is fullfilled.

# %%
df.columns
# Out:
# Index(['runs', 'at_bats', 'hits', 'doubles', 'triples', 'homeruns', 'walks',
#        'strikeouts', 'stolen_bases', 'runs_allowed', 'earned_runs', 'ERA',
#        'shutouts', 'saves', 'complete_game', 'win'],
#       dtype='object')

# %% [markdown]
# we see the all columns name of the dataset

# %% [markdown]
# # so we start the EDA process

# %% [markdown]
# in that data set the label or the output are the win so we perform all ours process with the win.

# %%
sns.scatterplot(x='runs', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='runs', ylabel='win'>

# %% [markdown]
# we see that the when the runs are increses the wins are increse

# %%
sns.scatterplot(x='at_bats', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='at_bats', ylabel='win'>

# %%
sns.scatterplot(x='hits', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='hits', ylabel='win'>

# %%
sns.scatterplot(x='doubles', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='doubles', ylabel='win'>

# %%
sns.scatterplot(x='triples', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='triples', ylabel='win'>

# %%
sns.scatterplot(x='homeruns', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='homeruns', ylabel='win'>

# %%
sns.scatterplot(x='walks', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='walks', ylabel='win'>

# %%
sns.scatterplot(x='strikeouts', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='strikeouts', ylabel='win'>

# %%
sns.scatterplot(x='stolen_bases', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='stolen_bases', ylabel='win'>

# %%
sns.scatterplot(x='runs_allowed', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='runs_allowed', ylabel='win'>

# %% [markdown]
# when the runs_allowed are increse the win are increse

# %%
sns.scatterplot(x='earned_runs', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='earned_runs', ylabel='win'>

# %%
sns.scatterplot(x='ERA', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='ERA', ylabel='win'>

# %%
sns.scatterplot(x='shutouts', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='shutouts', ylabel='win'>

# %%
sns.scatterplot(x='saves', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='saves', ylabel='win'>

# %%
sns.scatterplot(x='complete_game', y='win', data=df)
# Out:
# <AxesSubplot:xlabel='complete_game', ylabel='win'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30 entries, 95 to 68
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   runs           30 non-null     int64
#  1   at_bats        30 non-null     int64
#  2   hits           30 non-null     int64
#  3   doubles        30 non-null     int64
#  4   triples        30 non-null     int64
#  5   homeruns       30 non-null     int64
#  6   walks          30 non-null     int64
#  7   strikeouts     30 non-null     int64
#  8   stolen_bases   30 non-null     int64
#  9   runs_allowed   30 non-null     int64
#  10  earned_runs    30 non-null     int64
#  11  ERA            30 non-null     float64
#  12  shutouts       30 non-null     int64
#  13  saves          30 non-null     int64
#  14  complete_game  30 non-null     int64
#  15  win            30 non-null     int64
# dtypes: float64(1), int64(15)
# memory usage: 4.0 KB

# %% [markdown]
# we see that the all numbers are available

# %%
sns.catplot(x='runs',y='win',data=df)

# %% [markdown]
# # describe of the dataset

# %%
df.describe()
# Out:
#              runs      at_bats         hits     doubles    triples  \
# count   30.000000    30.000000    30.000000   30.000000  30.000000
# mean   688.233333  5516.266667  1403.533333  274.733333  31.300000
# std     58.761754    70.467372    57.140923   18.095405  10.452355
# min    573.000000  5385.000000  1324.000000  236.000000  13.000000
# 25%    651.250000  5464.000000  1363.000000  262.250000  23.000000
# 50%    689.000000  5510.000000  1382.500000  275.500000  31.000000
# 75%    718.250000  5570.000000  1451.500000  288.750000  39.000000
# max    891.000000  5649.000000  1515.000000  308.000000  49.000000
#
#          homeruns       walks  strikeouts  stolen_bases  runs_allowed  \
# count   30.000000   30.000000    30.00000     30.000000     30.000000
# mean   163.633333  469.100000  1248.20000     83.500000    688.233333
# std     31.823309   57.053725   103.75947     22.815225     72.108005
# min    100.000000  375.000000   973.00000     44.000000    525.000000
# ...

# %% [raw]
# in that describe dataset we see that the all columns count of the all the columns.
# we see the mean values of all columns.
# we see the standard derivation values of all columns.
# we see the min values of all columns.
# we see the 25 percentile values of all columns.
# we see the 50 percentile values of all columns.
# we see the 75 percentile values of all columns.
# we see the maximun values of all columns.
#
# in that describe datset we see that the outliers are present in the columns.like shutouts and saves

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True ,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see the correlation with all the columns with all other columns.

# %%
df.corr()
# Out:
#                    runs   at_bats      hits   doubles   triples  homeruns  \
# runs           1.000000  0.319464  0.482856  0.560084 -0.070072  0.671283
# at_bats        0.319464  1.000000  0.739122  0.453370  0.435422 -0.066983
# hits           0.482856  0.739122  1.000000  0.566847  0.478694 -0.090855
# doubles        0.560084  0.453370  0.566847  1.000000  0.220490  0.056292
# triples       -0.070072  0.435422  0.478694  0.220490  1.000000 -0.430915
# homeruns       0.671283 -0.066983 -0.090855  0.056292 -0.430915  1.000000
# walks          0.402452 -0.136414 -0.118281  0.302700 -0.454949  0.425691
# strikeouts    -0.054726 -0.106022 -0.398830 -0.150752 -0.141196  0.359923
# stolen_bases   0.081367  0.372618  0.413444  0.195027  0.457437 -0.136567
# runs_allowed  -0.041623  0.316010  0.224324 -0.218160  0.314125 -0.103903
# earned_runs   -0.041245  0.309686  0.252489 -0.235531  0.340225 -0.085922
# ERA           -0.049281  0.255551  0.231172 -0.254854  0.330951 -0.090917
# ...

# %% [markdown]
# in that set we see the correlation with all columns.
# get the proper view we used the heatmap.

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(), annot=True , fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see that the correaltion between the runs_allowed and earned_runs are very high correlated so we delete one column and also with the ERA

# %%
df=df.drop('ERA',axis=1)

# %%
df.shape
# Out:
# (30, 15)

# %%
plt.figure(figsize=(22,7))
df.corr()['win'].sort_values(ascending=False).drop(['win']).plot(kind='bar', color='c')
# Out:
# <AxesSubplot:>

# %%
df.skew()
# Out:
# runs             1.200786
# at_bats          0.183437
# hits             0.670254
# doubles         -0.230650
# triples          0.129502
# homeruns         0.516441
# walks            0.158498
# strikeouts      -0.156065
# stolen_bases     0.479893
# runs_allowed     0.045734
# earned_runs      0.058710
# shutouts         0.736845
# saves            0.565790
# complete_game    0.657524
# win              0.890132
# dtype: float64

# %%
from scipy.stats import skew
import warnings
warnings.filterwarnings('ignore')

# %%
for i in df:
    print(i)
    print(skew(df[i]))
    
    plt.figure()
    sns.distplot(df[i])
    plt.show()
# Out:
# runs
# 1.1398931660307043
# at_bats
# 0.17413429032352498
# hits
# 0.6362644174348592
# doubles
# -0.2189534077067715
# triples
# 0.12293523975827839
# homeruns
# 0.49025146140832154
# walks
# 0.15046085271433388
# strikeouts
# -0.14815122992357777
# stolen_bases
# 0.4555569751737513
# runs_allowed
# 0.04341475534967941
# earned_runs
# 0.055732557686200515
# shutouts
# 0.6994790420153237
# saves
# 0.5370985776239573
# complete_game
# 0.6241798071870271
# win
# 0.8449922672006391

# %%
plt.figure(figsize=(18,8))
sns.heatmap(df.corr(),annot=True)
plt.show()

# %% [markdown]
# our main focus is on to the win column.

# %% [markdown]
# # checking the outliers

# %%
df.dtypes
# Out:
# runs             int64
# at_bats          int64
# hits             int64
# doubles          int64
# triples          int64
# homeruns         int64
# walks            int64
# strikeouts       int64
# stolen_bases     int64
# runs_allowed     int64
# earned_runs      int64
# shutouts         int64
# saves            int64
# complete_game    int64
# win              int64
# dtype: object

# %%
plt.figure(figsize=(18,8))
sns.boxplot(data=df,x='runs',y='win')
plt.show()

# %%
df.columns
# Out:
# Index(['runs', 'at_bats', 'hits', 'doubles', 'triples', 'homeruns', 'walks',
#        'strikeouts', 'stolen_bases', 'runs_allowed', 'earned_runs', 'shutouts',
#        'saves', 'complete_game', 'win'],
#       dtype='object')

# %%
df['runs'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['at_bats'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['hits'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['doubles'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['triples'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['homeruns'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['walks'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['strikeouts'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['stolen_bases'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['runs_allowed'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['earned_runs'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['shutouts'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['saves'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['complete_game'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['win'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# in that dataset the outliers are present but in few countity so we remove this outliers using the zscore

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([5], dtype=int64), array([0], dtype=int64))

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#      runs  at_bats  hits  doubles  triples  homeruns  walks  strikeouts  \
# 95    724     5575  1497      300       42       139    383         973
# 83    696     5467  1349      277       44       156    439        1264
# 81    669     5439  1395      303       29       141    533        1157
# 76    622     5533  1381      260       27       136    404        1231
# 74    689     5605  1515      289       49       151    455        1259
# 87    764     5567  1397      272       19       212    554        1227
# 81    713     5485  1370      246       20       217    418        1331
# 80    644     5485  1383      278       32       167    436        1310
# 78    748     5640  1495      294       33       161    478        1148
# 88    751     5511  1419      279       32       172    503        1233
# 86    729     5459  1363      278       26       230    486        1392
# 85    661     5417  1331      243       21       176    435        1150
# ...

# %% [markdown]
# seprating the columns

# %%
features=df.drop("win", axis=1)
target=df["win"]

# %%
import warnings
warnings.filterwarnings('ignore')
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split

# %%
# only for the selection the random value
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.3,random_state=i)
    lr.fit(features_train , target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"at random state {i}, the traing accuracy is- {r2_score(target_train,pred_train)}")
    print(f"at random state {i}, the testing accuracy is-{r2_score(target_test,pred_test)}")
    print('\n')
# Out:
# at random state 0, the traing accuracy is- 0.6915951562585838
# at random state 0, the testing accuracy is--1.8113797608047246
#
#
# at random state 1, the traing accuracy is- 0.6737892098548106
# at random state 1, the testing accuracy is--1.1171763005714155
#
#
# at random state 2, the traing accuracy is- 0.7753311590075428
# at random state 2, the testing accuracy is--5.630922203599442
#
#
# at random state 3, the traing accuracy is- 0.7921216142275098
# at random state 3, the testing accuracy is--0.8382587240845891
#
#
# at random state 4, the traing accuracy is- 0.6966494872736042
# at random state 4, the testing accuracy is--2.8940563456263213
#
#
# at random state 5, the traing accuracy is- 0.6386011823110318
# at random state 5, the testing accuracy is--0.6868354995998083
#
#
# at random state 6, the traing accuracy is- 0.8252348629082573
# at random state 6, the testing accuracy is--12.425271291783876
#
#
# at random state 7, the traing accuracy is- 0.8027406124321221
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.3,random_state=59)

# %%
lr.fit(features_train , target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# -0.7126249884946096

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test , y=pred_test, color='r')
plt.xlabel('actual charger')
plt.ylabel('predicted charger')
plt.title('Linear regression ')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss=r2_score(target_test, pred_ls)
lss
# Out:
# -0.28845581562988754

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# -0.9656505126572015

# %% [markdown]
# # esemble technique

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'], 'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clt=GridSearchCV(rf,parameters)
clt.fit(features_train,target_train)

print(clt.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'sqrt'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='sqrt')
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision=rf.predict(features_test)

rfs=r2_score(target_test,pred_decision)
print('R2 score', rfs*100)

rfscore=cross_val_score(rf,features,target,cv=5)
rfc=rfscore.mean()
print('Cross Val Score', rfc*100)
# Out:
# R2 score -26.10003597122301
# Cross Val Score -90.03708072891511

# %% [markdown]
# getting the model result

# %%
import pickle
filename='basketball.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# conclusion

# %%
loaded_model=pickle.load(open('basketball.pkl','rb'))
result=loaded_model.score(features_test, target_test)
print(result)
# Out:
# -0.2610003597122301

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=['predicted','original'])
conclusion
# Out:
#                0     1      2     3      4       5     6      7      8
# predicted  94.58  91.3  88.97  92.2  96.69  101.88  90.8  97.98  95.47
# original   94.58  91.3  88.97  92.2  96.69  101.88  90.8  97.98  95.47
