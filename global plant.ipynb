# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('global_plant.csv')
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel other_fuel1 other_fuel2  \
# 0            2.5   28.1839    73.2407        Solar         NaN         NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 907 entries, 0 to 906
# Data columns (total 27 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   907 non-null    object
#  1   country_long              907 non-null    object
#  2   name                      907 non-null    object
#  3   gppd_idnr                 907 non-null    object
#  4   capacity_mw               907 non-null    float64
#  5   latitude                  861 non-null    float64
#  6   longitude                 861 non-null    float64
#  7   primary_fuel              907 non-null    object
#  8   other_fuel1               198 non-null    object
#  9   other_fuel2               1 non-null      object
#  10  other_fuel3               0 non-null      float64
#  11  commissioning_year        527 non-null    float64
#  12  owner                     342 non-null    object
# ...

# %% [markdown]
# we see that in that data set there are lost of null values are present so where the most null value are present we delete that column

# %%
df1=df.drop(['other_fuel2','other_fuel3','wepp_id','generation_gwh_2019','estimated_generation_gwh','other_fuel1','wepp_id'],axis=1)

# %%
df1
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
df=df1.dropna(how='all',axis=1)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
df=df.dropna(thresh=11)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
df.isnull().sum()
# Out:
# country                     0
# country_long                0
# name                        0
# gppd_idnr                   0
# capacity_mw                 0
# latitude                   27
# longitude                  27
# primary_fuel                0
# commissioning_year        365
# owner                     560
# source                      0
# url                         0
# geolocation_source          0
# year_of_capacity_data     369
# generation_gwh_2014       490
# generation_gwh_2015       466
# generation_gwh_2016       454
# generation_gwh_2017       448
# generation_gwh_2018       440
# generation_data_source    439
# dtype: int64

# %% [markdown]
# we see that there are more than 50 percent data have a null values so greather than 500 we delete this columns.

# %%
df=df.drop('owner',axis=1)

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
df=df.fillna(method='pad')

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
df.isnull().sum()
# Out:
# country                   0
# country_long              0
# name                      0
# gppd_idnr                 0
# capacity_mw               0
# latitude                  0
# longitude                 0
# primary_fuel              0
# commissioning_year        0
# source                    0
# url                       0
# geolocation_source        0
# year_of_capacity_data     3
# generation_gwh_2014       3
# generation_gwh_2015       3
# generation_gwh_2016       3
# generation_gwh_2017       3
# generation_gwh_2018       3
# generation_data_source    3
# dtype: int64

# %% [markdown]
# now we see that we fill all the data so we go to the ferther process

# %%
df.shape
# Out:
# (888, 19)

# %% [markdown]
# our target veriable is primary fuel and capacity_mw

# %%
df['name'].value_counts()
# Out:
# ACME Solar Tower             1
# Patnaik Hatti Wind Farm      1
# PRAGATI CCCP -III            1
# PRAGATI CCGT                 1
# PRIYADARSHNI JURALA          1
#                             ..
# K.N. Ram Kaltek Wind Farm    1
# KADAMPARI                    1
# KADANA                       1
# KADRA                        1
# iEnergy Theni Wind Farm      1
# Name: name, Length: 888, dtype: int64

# %% [markdown]
# we change the catogerical data into the numarical data

# %%
df
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#      capacity_mw  latitude  longitude primary_fuel  commissioning_year  \
# 0            2.5   28.1839    73.2407        Solar              2011.0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df1=df.select_dtypes(object)

# %%
df1
# Out:
#     country country_long                          name   gppd_idnr  \
# 0       IND        India              ACME Solar Tower  WRI1020239
# 1       IND        India           ADITYA CEMENT WORKS  WRI1019881
# 2       IND        India      AES Saurashtra Windfarms  WRI1026669
# 3       IND        India                   AGARTALA GT  IND0000001
# 4       IND        India                  AKALTARA TPP  IND0000002
# ..      ...          ...                           ...         ...
# 902     IND        India                  YERMARUS TPP  IND0000513
# 903     IND        India  Yelesandra Solar Power Plant  WRI1026222
# 904     IND        India  Yelisirur wind power project  WRI1026776
# 905     IND        India                   ZAWAR MINES  WRI1019901
# 906     IND        India       iEnergy Theni Wind Farm  WRI1026761
#
#     primary_fuel                                source  \
# 0          Solar  National Renewable Energy Laboratory
# ...

# %%
for i in df1:
    le=LabelEncoder()
    df1[i]= le.fit_transform(df1[i])

# %%
df1
# Out:
#      country  country_long  name  gppd_idnr  primary_fuel  source  url  \
# 0          0             0     0        656             6     109  126
# 1          0             0     1        519             1     174  169
# 2          0             0     2        845             7      21  196
# 3          0             0     3          0             2      22   58
# 4          0             0     4          1             1      22   58
# ..       ...           ...   ...        ...           ...     ...  ...
# 902        0             0   883        491             1      22   58
# 903        0             0   884        814             6      77   22
# 904        0             0   885        873             7      21  246
# 905        0             0   886        539             1      59   82
# 906        0             0   887        858             7      21  234
#
#      geolocation_source  generation_data_source
# 0                     1                       1
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 888 entries, 0 to 906
# Data columns (total 19 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   country                 888 non-null    object
#  1   country_long            888 non-null    object
#  2   name                    888 non-null    object
#  3   gppd_idnr               888 non-null    object
#  4   capacity_mw             888 non-null    float64
#  5   latitude                888 non-null    float64
#  6   longitude               888 non-null    float64
#  7   primary_fuel            888 non-null    object
#  8   commissioning_year      888 non-null    float64
#  9   source                  888 non-null    object
#  10  url                     888 non-null    object
#  11  geolocation_source      888 non-null    object
#  12  year_of_capacity_data   885 non-null    float64
#  13  generation_gwh_2014     885 non-null    float64
# ...

# %%
df2=df.select_dtypes(float)

# %%
df2
# Out:
#      capacity_mw  latitude  longitude  commissioning_year  \
# 0            2.5   28.1839    73.2407              2011.0
# 1           98.0   24.7663    74.6090              2011.0
# 2           39.2   21.9038    69.3732              2011.0
# 3          135.0   23.8712    91.3602              2004.0
# 4         1800.0   21.9603    82.4091              2015.0
# ..           ...       ...        ...                 ...
# 902       1600.0   16.2949    77.3568              2016.0
# 903          3.0   12.8932    78.1654              2016.0
# 904         25.5   15.2758    75.5811              2016.0
# 905         80.0   24.3500    73.7477              2016.0
# 906         16.5    9.9344    77.4768              2016.0
#
#      year_of_capacity_data  generation_gwh_2014  generation_gwh_2015  \
# 0                      NaN                  NaN                  NaN
# 1                      NaN                  NaN                  NaN
# ...

# %%
df=pd.concat([df1, df2], axis=1)

# %%
df=df.dropna()
df
# Out:
#      country  country_long  name  gppd_idnr  primary_fuel  source  url  \
# 3          0             0     3          0             2      22   58
# 4          0             0     4          1             1      22   58
# 5          0             0     5          2             1      22   58
# 6          0             0     6          3             3      22   58
# 7          0             0     7          4             3      22   58
# ..       ...           ...   ...        ...           ...     ...  ...
# 902        0             0   883        491             1      22   58
# 903        0             0   884        814             6      77   22
# 904        0             0   885        873             7      21  246
# 905        0             0   886        539             1      59   82
# 906        0             0   887        858             7      21  234
#
#      geolocation_source  generation_data_source  capacity_mw  latitude  \
# ...

# %% [markdown]
# our target variable is primary_fuel and capacity_mw

# %% [markdown]
# firstly we visualize the data

# %%
sns.countplot(x='country', data=df)
print(df["country"].value_counts())
# Out:
# 0    885
# Name: country, dtype: int64

# %% [markdown]
# this all data of india.

# %%
sns.scatterplot('capacity_mw','source',data=df)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='source'>

# %%
sns.countplot(x='source', data=df)
print(df["source"].value_counts())
# Out:
# 22     519
# 21     108
# 84      10
# 110      6
# 134      4
#       ...
# 56       1
# 46       1
# 164      1
# 187      1
# 189      1
# Name: source, Length: 191, dtype: int64

# %%
sns.countplot(x='primary_fuel', data=df)
print(df["primary_fuel"].value_counts())
# Out:
# 1    257
# 3    251
# 6    122
# 7    107
# 2     69
# 0     50
# 5     20
# 4      9
# Name: primary_fuel, dtype: int64

# %% [markdown]
# we see that the coal are most used

# %%
sns.countplot(x='geolocation_source', data=df)
print(df["geolocation_source"].value_counts())
# Out:
# 2    765
# 0    119
# 1      4
# Name: geolocation_source, dtype: int64

# %% [markdown]
# WRI is most used geolocation_source

# %%
sns.scatterplot('gppd_idnr','primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='gppd_idnr', ylabel='primary_fuel'>

# %% [markdown]
# gppd is most in coal and gas

# %%
sns.countplot(x='generation_data_source', data=df)
print(df["generation_data_source"].value_counts())
# Out:
# 0    885
# 1      3
# Name: generation_data_source, dtype: int64

# %% [markdown]
# we see that all the data source is the Central Electricity Authority

# %%
sns.scatterplot(x='capacity_mw',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='primary_fuel'>

# %% [markdown]
# we see that the coal capacity_mw is very high. and wind capacity_mw is very low

# %%
sns.scatterplot(x='latitude',y='longitude',data=df)
# Out:
# <AxesSubplot:xlabel='latitude', ylabel='longitude'>

# %%
sns.countplot(x='commissioning_year', data=df)
print(df["commissioning_year"].value_counts())
# Out:
# 2013.0    75
# 2015.0    63
# 2000.0    53
# 2012.0    46
# 2017.0    38
#           ..
# 1954.0     1
# 1969.0     1
# 1959.0     1
# 1927.0     1
# 1953.0     1
# Name: commissioning_year, Length: 73, dtype: int64

# %% [markdown]
# we see that the commissioning_year is more in 2013 and 2015 also.

# %%
sns.countplot(x='year_of_capacity_data', data=df)
print(df["year_of_capacity_data"].value_counts())
# Out:
# 2019.0    885
# Name: year_of_capacity_data, dtype: int64

# %% [markdown]
# we see in that graph all the source are year_of_capacity_data is in 2019

# %%
sns.scatterplot(x='generation_gwh_2014',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2014', ylabel='primary_fuel'>

# %% [markdown]
# we see that the coal are more extened.

# %%
sns.scatterplot(x='generation_gwh_2015',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2015', ylabel='primary_fuel'>

# %% [markdown]
# the coal are very used in year 2015

# %%
sns.scatterplot(x='generation_gwh_2016',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2016', ylabel='primary_fuel'>

# %% [markdown]
# in year 2016 coal are wastly used.

# %%
sns.scatterplot(x='generation_gwh_2017',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2017', ylabel='primary_fuel'>

# %% [markdown]
# coal are highly used in year 2017

# %%
sns.scatterplot(x='generation_gwh_2018',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='generation_gwh_2018', ylabel='primary_fuel'>

# %% [markdown]
# in that graph we see that the coal are widly used in year 2018

# %%
sns.scatterplot(x='year_of_capacity_data',y='primary_fuel',data=df)
# Out:
# <AxesSubplot:xlabel='year_of_capacity_data', ylabel='primary_fuel'>

# %%
sns.countplot(x='generation_data_source', data=df)
print(df["generation_data_source"].value_counts())
# Out:
# 0    885
# Name: generation_data_source, dtype: int64

# %% [markdown]
# we see that the Central Electricity Authority are genrate all the data

# %%
sns.distplot(df['primary_fuel'])
# Out:
# <AxesSubplot:xlabel='primary_fuel', ylabel='Density'>

# %%
sns.distplot(df['capacity_mw'])
# Out:
# <AxesSubplot:xlabel='capacity_mw', ylabel='Density'>

# %% [markdown]
# destribution pf the data

# %%
df.describe()
# Out:
#        country  country_long        name   gppd_idnr  primary_fuel  \
# count    885.0         885.0  885.000000  885.000000    885.000000
# mean       0.0           0.0  445.000000  442.720904      3.124294
# std        0.0           0.0  255.621791  256.454211      2.239184
# min        0.0           0.0    3.000000    0.000000      0.000000
# 25%        0.0           0.0  224.000000  221.000000      1.000000
# 50%        0.0           0.0  445.000000  442.000000      3.000000
# 75%        0.0           0.0  666.000000  665.000000      6.000000
# max        0.0           0.0  887.000000  887.000000      7.000000
#
#            source         url  geolocation_source  generation_data_source  \
# count  885.000000  885.000000          885.000000                   885.0
# mean    43.745763   89.832768            1.727684                     0.0
# std     44.608856   64.573989            0.683824                     0.0
# ...

# %% [raw]
# in that dataset wee see that the all columns mean values and standard deviation.
#
# all columns information is see in describtion minimun values of the each column
# 25th percentile of each column
# 50th percentile of each column
# 75th percentile of the each column
# as well as we see the maximum value of the each columns.
# we see the count of each columns are present in respresctive column

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(22,7))
sns.heatmap(df.describe(),annot=True ,fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see that last 4 5 columns have the outliers presents

# %% [markdown]
# correlation

# %%
df.corr()
# Out:
#                         country  country_long      name  gppd_idnr  \
# country                     NaN           NaN       NaN        NaN
# country_long                NaN           NaN       NaN        NaN
# name                        NaN           NaN  1.000000   0.339192
# gppd_idnr                   NaN           NaN  0.339192   1.000000
# primary_fuel                NaN           NaN  0.031945   0.584943
# source                      NaN           NaN  0.002271   0.439094
# url                         NaN           NaN  0.026803   0.576865
# geolocation_source          NaN           NaN  0.033063  -0.483583
# generation_data_source      NaN           NaN       NaN        NaN
# capacity_mw                 NaN           NaN  0.063267  -0.327990
# latitude                    NaN           NaN -0.138215  -0.115886
# longitude                   NaN           NaN  0.007348  -0.382141
# commissioning_year          NaN           NaN -0.039514   0.163102
# ...

# %%
plt.figure(figsize=(22,7))
sns.heatmap(df.corr(), annot=True , fmt='0.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see 0 or empthy becuse the there are 0 value are present.

# %%
plt.figure(figsize=(22,7))
df.corr()['primary_fuel'].sort_values(ascending=False).drop(['primary_fuel']).plot(kind='bar', color='c')
# Out:
# <AxesSubplot:>

# %% [markdown]
# we see the correlation with our target variable.

# %% [markdown]
# we see the skewness

# %%
df.skew()
# Out:
# country                   0.000000
# country_long              0.000000
# name                      0.000000
# gppd_idnr                 0.004110
# primary_fuel              0.523266
# source                    1.840733
# url                       1.578344
# geolocation_source       -2.125358
# generation_data_source    0.000000
# capacity_mw               3.080464
# latitude                 -0.124290
# longitude                 1.130921
# commissioning_year       -1.177533
# year_of_capacity_data     0.000000
# generation_gwh_2014       3.026716
# generation_gwh_2015       3.187730
# generation_gwh_2016       3.076910
# generation_gwh_2017       3.368099
# generation_gwh_2018       3.212299
# dtype: float64

# %% [markdown]
# we see that the skewness are mostly present .
# the skewness is 0 is not usefull for us.

# %% [markdown]
# outliers checking.

# %%
df.dtypes
# Out:
# country                     int32
# country_long                int32
# name                        int32
# gppd_idnr                   int32
# primary_fuel                int32
# source                      int32
# url                         int32
# geolocation_source          int32
# generation_data_source      int32
# capacity_mw               float64
# latitude                  float64
# longitude                 float64
# commissioning_year        float64
# year_of_capacity_data     float64
# generation_gwh_2014       float64
# generation_gwh_2015       float64
# generation_gwh_2016       float64
# generation_gwh_2017       float64
# generation_gwh_2018       float64
# dtype: object

# %%
df['gppd_idnr'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# there are no outliers are present.

# %%
df['primary_fuel'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['source'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['url'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['geolocation_source'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['generation_data_source'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['capacity_mw'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['latitude'].plot.box()
# Out:
# <AxesSubplot:>

# %%
df['longitude'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['commissioning_year'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['generation_gwh_2014'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['generation_gwh_2015'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['generation_gwh_2016'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['generation_gwh_2017'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %%
df['generation_gwh_2018'].plot.box()
# Out:
# <AxesSubplot:>

# %% [markdown]
# outliers are present.

# %% [markdown]
# use zscore to remove outliers.

# %%
df.shape
# Out:
# (885, 19)

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 12,  12,  12,  66,  75, 138, 142, 174, 178, 186, 237, 291, 300,
#         313, 315, 325, 332, 337, 352, 355, 356, 356, 356, 356, 356, 356,
#         367, 407, 418, 440, 472, 483, 483, 483, 483, 483, 483, 484, 484,
#         484, 484, 484, 484, 489, 498, 508, 527, 528, 561, 565, 589, 626,
#         636, 636, 636, 636, 636, 636, 644, 644, 644, 644, 644, 644, 645,
#         645, 645, 645, 645, 646, 646, 646, 646, 646, 647, 647, 647, 647,
#         647, 648, 648, 648, 648, 648, 648, 649, 649, 649, 649, 649, 650,
#         650, 650, 650, 650, 651, 651, 651, 651, 651, 652, 652, 652, 652,
#         652, 653, 653, 653, 653, 653, 654, 654, 654, 654, 654, 655, 655,
#         655, 655, 655, 656, 656, 656, 656, 656, 656, 657, 657, 657, 657,
#         657, 658, 658, 658, 658, 658, 659, 659, 659, 659, 659, 660, 660,
#         660, 660, 660, 675, 681, 681, 681, 681, 681, 681, 682, 682, 682,
#         682, 682, 695, 696, 712, 712, 712, 712, 712, 712, 713, 713, 714,
# ...

# %%
df
# Out:
#      country  country_long  name  gppd_idnr  primary_fuel  source  url  \
# 3          0             0     3          0             2      22   58
# 4          0             0     4          1             1      22   58
# 5          0             0     5          2             1      22   58
# 6          0             0     6          3             3      22   58
# 7          0             0     7          4             3      22   58
# ..       ...           ...   ...        ...           ...     ...  ...
# 902        0             0   883        491             1      22   58
# 903        0             0   884        814             6      77   22
# 904        0             0   885        873             7      21  246
# 905        0             0   886        539             1      59   82
# 906        0             0   887        858             7      21  234
#
#      geolocation_source  generation_data_source  capacity_mw  latitude  \
# ...

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
# Empty DataFrame
# Columns: [country, country_long, name, gppd_idnr, primary_fuel, source, url, geolocation_source, generation_data_source, capacity_mw, latitude, longitude, commissioning_year, year_of_capacity_data, generation_gwh_2014, generation_gwh_2015, generation_gwh_2016, generation_gwh_2017, generation_gwh_2018]
# Index: []

# %%
df_new_z.shape
# Out:
# (0, 19)

# %% [markdown]
# seprate the columns and target

# %%
features=df.drop("primary_fuel", axis=1)
target=df["primary_fuel"]

# %%
from sklearn.preprocessing import MinMaxScaler
mns=MinMaxScaler()
from sklearn.linear_model import LinearRegression
lr=LinearRegression()
from sklearn.metrics import r2_score
from sklearn.model_selection import train_test_split
import warnings
warnings.filterwarnings('ignore')

# %%
# only for the selection the random value
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train , target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"at random state {i}, the traing accuracy is- {r2_score(target_train,pred_train)}")
    print(f"at random state {i}, the testing accuracy is-{r2_score(target_test,pred_test)}")
    print('\n')
# Out:
# at random state 0, the traing accuracy is- 0.7374407648777068
# at random state 0, the testing accuracy is-0.7335786770982868
#
#
# at random state 1, the traing accuracy is- 0.7525398512220316
# at random state 1, the testing accuracy is-0.6681630796333189
#
#
# at random state 2, the traing accuracy is- 0.7531730590694392
# at random state 2, the testing accuracy is-0.6584148006686719
#
#
# at random state 3, the traing accuracy is- 0.7447606853276916
# at random state 3, the testing accuracy is-0.7000345626456852
#
#
# at random state 4, the traing accuracy is- 0.7447673255328202
# at random state 4, the testing accuracy is-0.7006324023150174
#
#
# at random state 5, the traing accuracy is- 0.7470334620055901
# at random state 5, the testing accuracy is-0.6922072777788222
#
#
# at random state 6, the traing accuracy is- 0.7450194369999814
# at random state 6, the testing accuracy is-0.6851661198758556
#
#
# at random state 7, the traing accuracy is- 0.725899981507886
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=9)

# %%
lr.fit(features_train , target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.8086138410572071

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test , y=pred_test, color='r')
plt.xlabel('actual charger')
plt.ylabel('predicted charger')
plt.title('Linear regression ')
plt.show()

# %% [markdown]
# regularazation

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'alpha': 0.0001, 'random_state': 0}

# %%
ls=Lasso(alpha=0.0001,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss=r2_score(target_test, pred_ls)
lss
# Out:
# 0.8086049712706143

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.7189339357237421

# %% [markdown]
# esemble tech

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'], 'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clt=GridSearchCV(rf,parameters)
clt.fit(features_train,target_train)

print(clt.best_params_)
# Out:
# {'criterion': 'mse', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mse',max_features='auto')
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision=rf.predict(features_test)

rfs=r2_score(target_test,pred_decision)
print('R2 score', rfs*100)

rfscore=cross_val_score(rf,features,target,cv=5)
rfc=rfscore.mean()
print('Cross Val Score', rfc*100)
# Out:
# R2 score 93.88890673725433
# Cross Val Score 90.83496154190824

# %% [raw]
# *****************************************************************************************************************************************************************************************************************************************************************************************************8

# %% [markdown]
# this is the prediction of the primary_fual column..

# %%
df.skew()
# Out:
# gppd_idnr              0.004110
# primary_fuel           0.523266
# source                 1.840733
# url                    1.578344
# geolocation_source    -2.125358
# capacity_mw            3.080464
# latitude              -0.124290
# longitude              1.130921
# commissioning_year    -1.177533
# generation_gwh_2014    3.026716
# generation_gwh_2015    3.187730
# generation_gwh_2016    3.076910
# generation_gwh_2017    3.368099
# generation_gwh_2018    3.212299
# dtype: float64

# %%
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
threshold=3
np.where(z>3)
# Out:
# (array([ 12,  12,  12,  66,  75, 138, 142, 174, 178, 186, 237, 291, 300,
#         313, 315, 325, 332, 337, 352, 355, 356, 356, 356, 356, 356, 356,
#         367, 407, 418, 440, 472, 483, 483, 483, 483, 483, 483, 484, 484,
#         484, 484, 484, 484, 489, 498, 508, 527, 528, 561, 565, 589, 626,
#         636, 636, 636, 636, 636, 636, 644, 644, 644, 644, 644, 644, 645,
#         645, 645, 645, 645, 646, 646, 646, 646, 646, 647, 647, 647, 647,
#         647, 648, 648, 648, 648, 648, 648, 649, 649, 649, 649, 649, 650,
#         650, 650, 650, 650, 651, 651, 651, 651, 651, 652, 652, 652, 652,
#         652, 653, 653, 653, 653, 653, 654, 654, 654, 654, 654, 655, 655,
#         655, 655, 655, 656, 656, 656, 656, 656, 656, 657, 657, 657, 657,
#         657, 658, 658, 658, 658, 658, 659, 659, 659, 659, 659, 660, 660,
#         660, 660, 660, 675, 681, 681, 681, 681, 681, 681, 682, 682, 682,
#         682, 682, 695, 696, 712, 712, 712, 712, 712, 712, 713, 713, 714,
# ...

# %%
df_new_z=df[(z<3).all(axis=1)]
df_new_z
# Out:
#      gppd_idnr  primary_fuel  source  url  geolocation_source  capacity_mw  \
# 3            0             2      22   58                   2        135.0
# 4            1             1      22   58                   2       1800.0
# 5            2             1      22   58                   2        250.0
# 6            3             3      22   58                   2         60.0
# 7            4             3      22   58                   2        192.0
# ..         ...           ...     ...  ...                 ...          ...
# 902        491             1      22   58                   2       1600.0
# 903        814             6      77   22                   0          3.0
# 904        873             7      21  246                   2         25.5
# 905        539             1      59   82                   2         80.0
# 906        858             7      21  234                   2         16.5
#
#      latitude  longitude  commissioning_year  generation_gwh_2014  \
# ...

# %%
features=df_new_z.drop("capacity_mw", axis=1)
target=df_new_z["capacity_mw"]

# %%
# only for the selection the random value
for i in range(0,100):
    features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=i)
    lr.fit(features_train , target_train)
    pred_train=lr.predict(features_train)
    pred_test=lr.predict(features_test)
    print(f"at random state {i}, the traing accuracy is- {r2_score(target_train,pred_train)}")
    print(f"at random state {i}, the testing accuracy is-{r2_score(target_test,pred_test)}")
    print('\n')
# Out:
# at random state 0, the traing accuracy is- 0.47747579827688147
# at random state 0, the testing accuracy is-0.3936042127368006
#
#
# at random state 1, the traing accuracy is- 0.4528576899510328
# at random state 1, the testing accuracy is-0.4865794157546366
#
#
# at random state 2, the traing accuracy is- 0.4650460285655377
# at random state 2, the testing accuracy is-0.4470360888898005
#
#
# at random state 3, the traing accuracy is- 0.444794917590144
# at random state 3, the testing accuracy is-0.5046937888955202
#
#
# at random state 4, the traing accuracy is- 0.4619878702471055
# at random state 4, the testing accuracy is-0.4393221820329508
#
#
# at random state 5, the traing accuracy is- 0.44878987448803187
# at random state 5, the testing accuracy is-0.5105093009663011
#
#
# at random state 6, the traing accuracy is- 0.4518780110181677
# at random state 6, the testing accuracy is-0.4989121420271563
#
#
# at random state 7, the traing accuracy is- 0.46701643045871033
# ...

# %%
features_train,features_test,target_train,target_test=train_test_split(features,target,test_size=0.2,random_state=72)

# %%
lr.fit(features_train , target_train)
# Out:
# LinearRegression()

# %%
pred_test=lr.predict(features_test)

# %%
print(r2_score(target_test,pred_test))
# Out:
# 0.5366154374040464

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,6))
plt.scatter(x=target_test , y=pred_test, color='r')
plt.xlabel('actual charger')
plt.ylabel('predicted charger')
plt.title('Linear regression ')
plt.show()

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import cross_val_score

# %%
from sklearn.linear_model import Lasso
parameters={'alpha':[.0001, .001, .01,.1,1,10],'random_state':list(range(0,10))}
ls=Lasso()
clf=GridSearchCV(ls,parameters)
clf.fit(features_train, target_train)

print(clf.best_params_)
# Out:
# {'alpha': 10, 'random_state': 0}

# %%
ls=Lasso(alpha=10,random_state=0)
ls.fit(features_train,target_train)
ls.score(features_train,target_train)
pred_ls = ls.predict(features_test)

lss=r2_score(target_test, pred_ls)
lss
# Out:
# 0.5289307401209069

# %%
cv_score=cross_val_score(ls,features,target,cv=5)
cv_mean=cv_score.mean()
cv_mean
# Out:
# 0.3948370209653524

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

parameters={'criterion':['mse','mae'], 'max_features':['auto','sqrt','log2']}
rf=RandomForestRegressor()
clt=GridSearchCV(rf,parameters)
clt.fit(features_train,target_train)

print(clt.best_params_)
# Out:
# {'criterion': 'mae', 'max_features': 'auto'}

# %%
rf=RandomForestRegressor(criterion='mae',max_features='auto')
rf.fit(features_train, target_train)
rf.score(features_train, target_train)
pred_decision=rf.predict(features_test)

rfs=r2_score(target_test,pred_decision)
print('R2 score', rfs*100)

rfscore=cross_val_score(rf,features,target,cv=5)
rfc=rfscore.mean()
print('Cross Val Score', rfc*100)
# Out:
# R2 score 72.82243121870451
# Cross Val Score 67.41705115348061

# %% [markdown]
# our program is ready

# %% [markdown]
# getting the model result

# %%
import pickle
filename='global.pkl'
pickle.dump(rf, open(filename, 'wb'))

# %% [markdown]
# conclusion

# %%
loaded_model=pickle.load(open('global.pkl','rb'))
result=loaded_model.score(features_test, target_test)
print(result)
# Out:
# 0.7282243121870451

# %%
conclusion=pd.DataFrame([loaded_model.predict(features_test)[:],pred_decision[:]],index=['predicted','original'])
conclusion
# Out:
#                  0        1          2       3     4       5     6    \
# predicted  340.88902  77.9885  1345.6244  64.011  7.63  661.14  46.3
# original   340.88902  77.9885  1345.6244  64.011  7.63  661.14  46.3
#
#                  7          8         9    ...     152      153      154  \
# predicted  556.69086  1475.6924  121.8675  ...  50.204  11.3745  110.065
# original   556.69086  1475.6924  121.8675  ...  50.204  11.3745  110.065
#
#                  155      156      157     158      159      160    161
# predicted  391.73192  1423.84  278.392  20.368  872.042  96.6585  71.47
# original   391.73192  1423.84  278.392  20.368  872.042  96.6585  71.47
#
# [2 rows x 162 columns]
